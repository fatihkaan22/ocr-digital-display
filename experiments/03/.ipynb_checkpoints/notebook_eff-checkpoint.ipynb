# %%
WORKSPACE_NAME = 'digital-meter'
MODEL_NAME = 'efficientdet_d1_coco17_tpu-32'

# %%
import argparse
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
#import cv2
import time
import tensorflow as tf
import os
import pathlib
from toolz.curried import *
# Out:
# 2022-12-18 11:29:44.067838: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-18 11:29:44.878300: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-18 11:29:44.878389: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-18 11:29:44.878399: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from object_detection.utils import config_util, label_map_util 
from object_detection.utils import visualization_utils as viz_utils
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
MOUNT_POINT = '/home/jupyter'
TENSORFLOW = os.path.join(MOUNT_POINT,'cse496','Tensorflow')
NOTEBOOK_WS = os.path.join(TENSORFLOW,'workspace',WORKSPACE_NAME)

# %%
paths = {
  'workspace': os.path.join(NOTEBOOK_WS),
  'images': os.path.join(NOTEBOOK_WS,'images'),
  'dataset': os.path.join(NOTEBOOK_WS,'dataset'),
  'labelmap': os.path.join(NOTEBOOK_WS,'annotations','label_map.pbtxt'),
  'models': os.path.join(TENSORFLOW,'models'),
  'annotations': os.path.join(NOTEBOOK_WS,'annotations'),
  'train_record': os.path.join(NOTEBOOK_WS,'annotations','train.record'),
  'test_record': os.path.join(NOTEBOOK_WS,'annotations','test.record'),
  'scripts': os.path.join(TENSORFLOW,'scripts'),
  'pre_trained_models': os.path.join(TENSORFLOW,'pre-trained-models'),
  'pre_trained_model': os.path.join(TENSORFLOW,'pre-trained-models',MODEL_NAME),
  'model': os.path.join(NOTEBOOK_WS,'models',MODEL_NAME),
  'pipeline': os.path.join(NOTEBOOK_WS,'models',MODEL_NAME,'pipeline.config'),
  'train_script': os.path.join(TENSORFLOW,'models','research','object_detection','model_main_tf2.py'),
  'export_script': os.path.join(TENSORFLOW,'models','research','object_detection','exporter_main_v2.py'),
  'infer_detections': os.path.join(TENSORFLOW,'models','research','object_detection','inference','infer_detections.py'),
  'exported_models': os.path.join(NOTEBOOK_WS,'exported_models'),
  'exported_model': os.path.join(NOTEBOOK_WS,'exported_models',MODEL_NAME),
}

# %%
category_index = label_map_util.create_category_index_from_labelmap(paths['labelmap'], use_display_name=True)

# %% [markdown]
# # Training Pipeline

# %%
# !mkdir -p {paths['model']}

# %%
copy_pre_trained_model_command = 'cp {} {}'.format(
  os.path.join(paths['pre_trained_model'],'pipeline.config'),
  os.path.join(paths['model'],'pipeline.config'),
) 
copy_pre_trained_model_command
# Out:
# 'cp /home/jupyter/cse496/Tensorflow/pre-trained-models/efficientdet_d1_coco17_tpu-32/pipeline.config /home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32/pipeline.config'

# %%
# !{copy_pre_trained_model_command}

# %%
config = config_util.get_configs_from_pipeline_file(paths['pipeline'])

config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      keep_aspect_ratio_resizer {
#        min_dimension: 640
#        max_dimension: 640
#        pad_to_max_dimension: true
#      }
#    }
#    feature_extractor {
#      type: "ssd_efficientnet-b1_bifpn_keras"
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          truncated_normal_initializer {
#            mean: 0.0
#            stddev: 0.029999999329447746
#          }
#        }
#        activation: SWISH
#        batch_norm {
#          decay: 0.9900000095367432
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#        force_use_bias: true
#      }
#      bifpn {
#        min_level: 3
#        max_level: 7
#        num_iterations: 4
#        num_filters: 88
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 1.0
#        x_scale: 1.0
#        height_scale: 1.0
#        width_scale: 1.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: SWISH
#          batch_norm {
#            decay: 0.9900000095367432
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#          force_use_bias: true
#        }
#        depth: 88
#        num_layers_before_predictor: 3
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 3
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.5
#        max_detections_per_class: 100
#        max_total_detections: 100
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 1.5
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#    add_background_class: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_scale_crop_and_pad_to_square {
#      output_size: 640
#      scale_min: 0.10000000149011612
#      scale_max: 2.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 300000
#          warmup_learning_rate: 0.0010000000474974513
#          warmup_steps: 2500
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 300000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/train2017-?????-of-00256.tfrecord"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(paths['pipeline'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)
    
pipeline_config.model.ssd.num_classes = len(category_index)
#pipeline_config.model.ssd.loss.localization_weight = 0.8
#pipeline_config.model.ssd.loss.classification_weight = 1.3
pipeline_config.train_config.batch_size = 8
#pipeline_config.train_config.num_steps = 200000
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['pre_trained_model'],'checkpoint','ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = 'detection'
pipeline_config.train_input_reader.label_map_path= paths['labelmap']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [paths['train_record']]
pipeline_config.eval_input_reader[0].label_map_path = paths['labelmap']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [paths['test_record']]

# %%
pipeline_config.train_config.data_augmentation_options.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_31705/2710779199.py in <module>
# ----> 1 pipeline_config.train_config.data_augmentation_options.pop()
#
# IndexError: list index (-1) out of range

# %%
pipeline_config
# Out:
# model {
#   ssd {
#     num_classes: 10
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 640
#         max_dimension: 640
#         pad_to_max_dimension: true
#       }
#     }
#     feature_extractor {
#       type: "ssd_efficientnet-b1_bifpn_keras"
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 3.9999998989515007e-05
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             mean: 0.0
#             stddev: 0.029999999329447746
#           }
#         }
#         activation: SWISH
#         batch_norm {
#           decay: 0.9900000095367432
#           scale: true
#           epsilon: 0.0010000000474974513
#         }
#         force_use_bias: true
#       }
#       bifpn {
#         min_level: 3
#         max_level: 7
#         num_iterations: 4
#         num_filters: 88
#       }
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 1.0
#         x_scale: 1.0
#         height_scale: 1.0
#         width_scale: 1.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 3.9999998989515007e-05
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               mean: 0.0
#               stddev: 0.009999999776482582
#             }
#           }
#           activation: SWISH
#           batch_norm {
#             decay: 0.9900000095367432
#             scale: true
#             epsilon: 0.0010000000474974513
#           }
#           force_use_bias: true
#         }
#         depth: 88
#         num_layers_before_predictor: 3
#         kernel_size: 3
#         class_prediction_bias_init: -4.599999904632568
#         use_depthwise: true
#       }
#     }
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         scales_per_octave: 3
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 9.99999993922529e-09
#         iou_threshold: 0.5
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_loss {
#         weighted_sigmoid_focal {
#           gamma: 1.5
#           alpha: 0.25
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     encode_background_as_zeros: true
#     normalize_loc_loss_by_codesize: true
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     add_background_class: false
#   }
# }
# train_config {
#   batch_size: 8
#   sync_replicas: true
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.07999999821186066
#           total_steps: 300000
#           warmup_learning_rate: 0.0010000000474974513
#           warmup_steps: 2500
#         }
#       }
#       momentum_optimizer_value: 0.8999999761581421
#     }
#     use_moving_average: false
#   }
#   fine_tune_checkpoint: "/home/jupyter/cse496/Tensorflow/pre-trained-models/efficientdet_d1_coco17_tpu-32/checkpoint/ckpt-0"
#   num_steps: 300000
#   startup_delay_steps: 0.0
#   replicas_to_aggregate: 8
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
#   fine_tune_checkpoint_type: "detection"
#   use_bfloat16: true
#   fine_tune_checkpoint_version: V2
# }
# train_input_reader {
#   label_map_path: "/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/train.record"
#   }
# }
# eval_config {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
#   batch_size: 1
# }
# eval_input_reader {
#   label_map_path: "/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/test.record"
#   }
# }

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(paths['pipeline'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
num_train_steps=300000
train_command = 'python {} --model_dir={} --pipeline_config_path={} --num_train_steps {}'.format(
    paths['train_script'], paths['model'], paths['pipeline'], num_train_steps
)

print(train_command)
# Out:
# python /home/jupyter/cse496/Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=/home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32 --pipeline_config_path=/home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32/pipeline.config --num_train_steps 300000

# %%
# Evaluation During Training: run parallel to training
eval_command = 'CUDA_VISIBLE_DEVICES="-1" python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}'.format(
    paths['train_script'],
    paths['model'],
    paths['pipeline'],
    paths['model']
)
print(eval_command)
# Out:
# CUDA_VISIBLE_DEVICES="-1" python /home/jupyter/cse496/Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=/home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32 --pipeline_config_path=/home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32/pipeline.config --checkpoint_dir=/home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32

# %%
# !{train_command}
# Out:
# 2022-12-18 12:02:34.698201: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-18 12:02:35.680996: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-18 12:02:35.681082: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-18 12:02:35.681098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-18 12:02:38.107807: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.121383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.123948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.126842: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-18 12:02:38.128078: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.130627: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.133061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.930878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.934674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.938000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-18 12:02:38.941203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13582 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1218 12:02:39.081379 139674028488512 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 300000
# I1218 12:02:39.084973 139674028488512 config_util.py:552] Maybe overwriting train_steps: 300000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1218 12:02:39.085131 139674028488512 config_util.py:552] Maybe overwriting use_bfloat16: False
# I1218 12:02:39.094965 139674028488512 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1218 12:02:39.095079 139674028488512 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I1218 12:02:39.095134 139674028488512 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 4
# I1218 12:02:39.099961 139674028488512 efficientnet_model.py:143] round_filter input=32 output=32
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.133714 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.137003 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.139135 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.140133 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.147551 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.151690 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.157875 139674028488512 efficientnet_model.py:143] round_filter input=32 output=32
# I1218 12:02:39.157967 139674028488512 efficientnet_model.py:143] round_filter input=16 output=16
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.175528 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.176431 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.178362 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.179300 139674028488512 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1218 12:02:39.395613 139674028488512 efficientnet_model.py:143] round_filter input=16 output=16
# I1218 12:02:39.395799 139674028488512 efficientnet_model.py:143] round_filter input=24 output=24
# I1218 12:02:39.995830 139674028488512 efficientnet_model.py:143] round_filter input=24 output=24
# I1218 12:02:39.996083 139674028488512 efficientnet_model.py:143] round_filter input=40 output=40
# I1218 12:02:40.439581 139674028488512 efficientnet_model.py:143] round_filter input=40 output=40
# I1218 12:02:40.439749 139674028488512 efficientnet_model.py:143] round_filter input=80 output=80
# I1218 12:02:41.023730 139674028488512 efficientnet_model.py:143] round_filter input=80 output=80
# I1218 12:02:41.023904 139674028488512 efficientnet_model.py:143] round_filter input=112 output=112
# I1218 12:02:41.593830 139674028488512 efficientnet_model.py:143] round_filter input=112 output=112
# I1218 12:02:41.593990 139674028488512 efficientnet_model.py:143] round_filter input=192 output=192
# I1218 12:02:42.297794 139674028488512 efficientnet_model.py:143] round_filter input=192 output=192
# I1218 12:02:42.297951 139674028488512 efficientnet_model.py:143] round_filter input=320 output=320
# I1218 12:02:42.589694 139674028488512 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1218 12:02:42.676800 139674028488512 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1218 12:02:42.726190 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/train.record']
# I1218 12:02:42.735247 139674028488512 dataset_builder.py:162] Reading unweighted datasets: ['/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/train.record']
# I1218 12:02:42.735434 139674028488512 dataset_builder.py:79] Reading record datasets for input file: ['/home/jupyter/cse496/Tensorflow/workspace/digital-meter/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1218 12:02:42.735507 139674028488512 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1218 12:02:42.735559 139674028488512 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1218 12:02:42.741503 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1218 12:02:42.757261 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1218 12:02:43.369212 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1218 12:02:46.487388 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1218 12:02:48.728133 139674028488512 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /opt/conda/lib/python3.7/site-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# 2022-12-18 12:03:17.704350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1218 12:03:32.755395 139653310609152 deprecation.py:560] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# WARNING:tensorflow:Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1218 12:03:43.301158 139653310609152 utils.py:86] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1218 12:03:57.952877 139653310609152 utils.py:86] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1218 12:04:11.139049 139653310609152 utils.py:86] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1218 12:04:25.038130 139653310609152 utils.py:86] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2022-12-18 12:04:34.286875: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientDet-D1/model/stack_0/block_1/drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# INFO:tensorflow:Step 100 per-step time 2.182s
# I1218 12:07:10.669347 139674028488512 model_lib_v2.py:707] Step 100 per-step time 2.182s
# INFO:tensorflow:{'Loss/classification_loss': 1.2697408,
#  'Loss/localization_loss': 0.019728415,
#  'Loss/regularization_loss': 0.029535513,
#  'Loss/total_loss': 1.3190048,
#  'learning_rate': 0.00416}
# I1218 12:07:10.669767 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 1.2697408,
#  'Loss/localization_loss': 0.019728415,
#  'Loss/regularization_loss': 0.029535513,
#  'Loss/total_loss': 1.3190048,
#  'learning_rate': 0.00416}
# INFO:tensorflow:Step 200 per-step time 1.326s
# I1218 12:09:23.193276 139674028488512 model_lib_v2.py:707] Step 200 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.6861839,
#  'Loss/localization_loss': 0.0078084306,
#  'Loss/regularization_loss': 0.029538462,
#  'Loss/total_loss': 0.7235308,
#  'learning_rate': 0.0073200003}
# I1218 12:09:23.193674 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.6861839,
#  'Loss/localization_loss': 0.0078084306,
#  'Loss/regularization_loss': 0.029538462,
#  'Loss/total_loss': 0.7235308,
#  'learning_rate': 0.0073200003}
# INFO:tensorflow:Step 300 per-step time 1.323s
# I1218 12:11:35.452748 139674028488512 model_lib_v2.py:707] Step 300 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.46681297,
#  'Loss/localization_loss': 0.0058703613,
#  'Loss/regularization_loss': 0.029552164,
#  'Loss/total_loss': 0.5022355,
#  'learning_rate': 0.010480001}
# I1218 12:11:35.453102 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.46681297,
#  'Loss/localization_loss': 0.0058703613,
#  'Loss/regularization_loss': 0.029552164,
#  'Loss/total_loss': 0.5022355,
#  'learning_rate': 0.010480001}
# INFO:tensorflow:Step 400 per-step time 1.324s
# I1218 12:13:47.840975 139674028488512 model_lib_v2.py:707] Step 400 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.47726944,
#  'Loss/localization_loss': 0.00540164,
#  'Loss/regularization_loss': 0.02957392,
#  'Loss/total_loss': 0.512245,
#  'learning_rate': 0.0136400005}
# I1218 12:13:47.841309 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.47726944,
#  'Loss/localization_loss': 0.00540164,
#  'Loss/regularization_loss': 0.02957392,
#  'Loss/total_loss': 0.512245,
#  'learning_rate': 0.0136400005}
# INFO:tensorflow:Step 500 per-step time 1.324s
# I1218 12:16:00.235125 139674028488512 model_lib_v2.py:707] Step 500 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.21142614,
#  'Loss/localization_loss': 0.004060233,
#  'Loss/regularization_loss': 0.029594045,
#  'Loss/total_loss': 0.24508043,
#  'learning_rate': 0.016800001}
# I1218 12:16:00.235447 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.21142614,
#  'Loss/localization_loss': 0.004060233,
#  'Loss/regularization_loss': 0.029594045,
#  'Loss/total_loss': 0.24508043,
#  'learning_rate': 0.016800001}
# INFO:tensorflow:Step 600 per-step time 1.323s
# I1218 12:18:12.584344 139674028488512 model_lib_v2.py:707] Step 600 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.21976858,
#  'Loss/localization_loss': 0.0063654897,
#  'Loss/regularization_loss': 0.029612688,
#  'Loss/total_loss': 0.25574675,
#  'learning_rate': 0.019960001}
# I1218 12:18:12.584696 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.21976858,
#  'Loss/localization_loss': 0.0063654897,
#  'Loss/regularization_loss': 0.029612688,
#  'Loss/total_loss': 0.25574675,
#  'learning_rate': 0.019960001}
# INFO:tensorflow:Step 700 per-step time 1.324s
# I1218 12:20:25.023902 139674028488512 model_lib_v2.py:707] Step 700 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.24243902,
#  'Loss/localization_loss': 0.0040595755,
#  'Loss/regularization_loss': 0.029638993,
#  'Loss/total_loss': 0.2761376,
#  'learning_rate': 0.023120001}
# I1218 12:20:25.024224 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.24243902,
#  'Loss/localization_loss': 0.0040595755,
#  'Loss/regularization_loss': 0.029638993,
#  'Loss/total_loss': 0.2761376,
#  'learning_rate': 0.023120001}
# INFO:tensorflow:Step 800 per-step time 1.327s
# I1218 12:22:37.698368 139674028488512 model_lib_v2.py:707] Step 800 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.13715346,
#  'Loss/localization_loss': 0.0028759215,
#  'Loss/regularization_loss': 0.029664546,
#  'Loss/total_loss': 0.16969393,
#  'learning_rate': 0.02628}
# I1218 12:22:37.698695 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.13715346,
#  'Loss/localization_loss': 0.0028759215,
#  'Loss/regularization_loss': 0.029664546,
#  'Loss/total_loss': 0.16969393,
#  'learning_rate': 0.02628}
# INFO:tensorflow:Step 900 per-step time 1.327s
# I1218 12:24:50.418683 139674028488512 model_lib_v2.py:707] Step 900 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.22266233,
#  'Loss/localization_loss': 0.0035576257,
#  'Loss/regularization_loss': 0.029685773,
#  'Loss/total_loss': 0.25590572,
#  'learning_rate': 0.02944}
# I1218 12:24:50.419062 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.22266233,
#  'Loss/localization_loss': 0.0035576257,
#  'Loss/regularization_loss': 0.029685773,
#  'Loss/total_loss': 0.25590572,
#  'learning_rate': 0.02944}
# INFO:tensorflow:Step 1000 per-step time 1.329s
# I1218 12:27:03.286326 139674028488512 model_lib_v2.py:707] Step 1000 per-step time 1.329s
# INFO:tensorflow:{'Loss/classification_loss': 0.0830577,
#  'Loss/localization_loss': 0.0024683985,
#  'Loss/regularization_loss': 0.029714657,
#  'Loss/total_loss': 0.11524076,
#  'learning_rate': 0.0326}
# I1218 12:27:03.286690 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0830577,
#  'Loss/localization_loss': 0.0024683985,
#  'Loss/regularization_loss': 0.029714657,
#  'Loss/total_loss': 0.11524076,
#  'learning_rate': 0.0326}
# INFO:tensorflow:Step 1100 per-step time 1.359s
# I1218 12:29:19.192876 139674028488512 model_lib_v2.py:707] Step 1100 per-step time 1.359s
# INFO:tensorflow:{'Loss/classification_loss': 0.06611458,
#  'Loss/localization_loss': 0.0028873559,
#  'Loss/regularization_loss': 0.029731136,
#  'Loss/total_loss': 0.09873307,
#  'learning_rate': 0.03576}
# I1218 12:29:19.193293 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.06611458,
#  'Loss/localization_loss': 0.0028873559,
#  'Loss/regularization_loss': 0.029731136,
#  'Loss/total_loss': 0.09873307,
#  'learning_rate': 0.03576}
# INFO:tensorflow:Step 1200 per-step time 1.325s
# I1218 12:31:31.660004 139674028488512 model_lib_v2.py:707] Step 1200 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.099748485,
#  'Loss/localization_loss': 0.002767399,
#  'Loss/regularization_loss': 0.029797228,
#  'Loss/total_loss': 0.13231312,
#  'learning_rate': 0.03892}
# I1218 12:31:31.660349 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.099748485,
#  'Loss/localization_loss': 0.002767399,
#  'Loss/regularization_loss': 0.029797228,
#  'Loss/total_loss': 0.13231312,
#  'learning_rate': 0.03892}
# INFO:tensorflow:Step 1300 per-step time 1.326s
# I1218 12:33:44.298448 139674028488512 model_lib_v2.py:707] Step 1300 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.076871075,
#  'Loss/localization_loss': 0.0028107408,
#  'Loss/regularization_loss': 0.029884452,
#  'Loss/total_loss': 0.109566264,
#  'learning_rate': 0.04208}
# I1218 12:33:44.298843 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.076871075,
#  'Loss/localization_loss': 0.0028107408,
#  'Loss/regularization_loss': 0.029884452,
#  'Loss/total_loss': 0.109566264,
#  'learning_rate': 0.04208}
# INFO:tensorflow:Step 1400 per-step time 1.325s
# I1218 12:35:56.755107 139674028488512 model_lib_v2.py:707] Step 1400 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.023250116,
#  'Loss/localization_loss': 0.0016288931,
#  'Loss/regularization_loss': 0.02991715,
#  'Loss/total_loss': 0.054796163,
#  'learning_rate': 0.04524}
# I1218 12:35:56.755425 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.023250116,
#  'Loss/localization_loss': 0.0016288931,
#  'Loss/regularization_loss': 0.02991715,
#  'Loss/total_loss': 0.054796163,
#  'learning_rate': 0.04524}
# INFO:tensorflow:Step 1500 per-step time 1.325s
# I1218 12:38:09.287871 139674028488512 model_lib_v2.py:707] Step 1500 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.021828024,
#  'Loss/localization_loss': 0.001451239,
#  'Loss/regularization_loss': 0.0298983,
#  'Loss/total_loss': 0.053177565,
#  'learning_rate': 0.0484}
# I1218 12:38:09.288185 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.021828024,
#  'Loss/localization_loss': 0.001451239,
#  'Loss/regularization_loss': 0.0298983,
#  'Loss/total_loss': 0.053177565,
#  'learning_rate': 0.0484}
# INFO:tensorflow:Step 1600 per-step time 1.328s
# I1218 12:40:22.065707 139674028488512 model_lib_v2.py:707] Step 1600 per-step time 1.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.031165842,
#  'Loss/localization_loss': 0.0018269211,
#  'Loss/regularization_loss': 0.029945692,
#  'Loss/total_loss': 0.06293845,
#  'learning_rate': 0.05156}
# I1218 12:40:22.066044 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.031165842,
#  'Loss/localization_loss': 0.0018269211,
#  'Loss/regularization_loss': 0.029945692,
#  'Loss/total_loss': 0.06293845,
#  'learning_rate': 0.05156}
# INFO:tensorflow:Step 1700 per-step time 1.324s
# I1218 12:42:34.486298 139674028488512 model_lib_v2.py:707] Step 1700 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.03290374,
#  'Loss/localization_loss': 0.0019350811,
#  'Loss/regularization_loss': 0.029955097,
#  'Loss/total_loss': 0.064793915,
#  'learning_rate': 0.05472}
# I1218 12:42:34.486643 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.03290374,
#  'Loss/localization_loss': 0.0019350811,
#  'Loss/regularization_loss': 0.029955097,
#  'Loss/total_loss': 0.064793915,
#  'learning_rate': 0.05472}
# INFO:tensorflow:Step 1800 per-step time 1.327s
# I1218 12:44:47.141878 139674028488512 model_lib_v2.py:707] Step 1800 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.02492833,
#  'Loss/localization_loss': 0.0013655261,
#  'Loss/regularization_loss': 0.029964471,
#  'Loss/total_loss': 0.05625833,
#  'learning_rate': 0.05788}
# I1218 12:44:47.142211 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.02492833,
#  'Loss/localization_loss': 0.0013655261,
#  'Loss/regularization_loss': 0.029964471,
#  'Loss/total_loss': 0.05625833,
#  'learning_rate': 0.05788}
# INFO:tensorflow:Step 1900 per-step time 1.326s
# I1218 12:46:59.752931 139674028488512 model_lib_v2.py:707] Step 1900 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.032593448,
#  'Loss/localization_loss': 0.0013698932,
#  'Loss/regularization_loss': 0.029923636,
#  'Loss/total_loss': 0.06388698,
#  'learning_rate': 0.06104}
# I1218 12:46:59.753238 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.032593448,
#  'Loss/localization_loss': 0.0013698932,
#  'Loss/regularization_loss': 0.029923636,
#  'Loss/total_loss': 0.06388698,
#  'learning_rate': 0.06104}
# INFO:tensorflow:Step 2000 per-step time 1.326s
# I1218 12:49:12.392424 139674028488512 model_lib_v2.py:707] Step 2000 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0045961016,
#  'Loss/localization_loss': 0.0009553177,
#  'Loss/regularization_loss': 0.029894372,
#  'Loss/total_loss': 0.03544579,
#  'learning_rate': 0.06420001}
# I1218 12:49:12.392763 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0045961016,
#  'Loss/localization_loss': 0.0009553177,
#  'Loss/regularization_loss': 0.029894372,
#  'Loss/total_loss': 0.03544579,
#  'learning_rate': 0.06420001}
# INFO:tensorflow:Step 2100 per-step time 1.349s
# I1218 12:51:27.307692 139674028488512 model_lib_v2.py:707] Step 2100 per-step time 1.349s
# INFO:tensorflow:{'Loss/classification_loss': 0.0070926407,
#  'Loss/localization_loss': 0.0008969523,
#  'Loss/regularization_loss': 0.029838623,
#  'Loss/total_loss': 0.03782822,
#  'learning_rate': 0.067360006}
# I1218 12:51:27.308041 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0070926407,
#  'Loss/localization_loss': 0.0008969523,
#  'Loss/regularization_loss': 0.029838623,
#  'Loss/total_loss': 0.03782822,
#  'learning_rate': 0.067360006}
# INFO:tensorflow:Step 2200 per-step time 1.326s
# I1218 12:53:39.924926 139674028488512 model_lib_v2.py:707] Step 2200 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.022637395,
#  'Loss/localization_loss': 0.0013277746,
#  'Loss/regularization_loss': 0.029783368,
#  'Loss/total_loss': 0.05374854,
#  'learning_rate': 0.070520006}
# I1218 12:53:39.925264 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.022637395,
#  'Loss/localization_loss': 0.0013277746,
#  'Loss/regularization_loss': 0.029783368,
#  'Loss/total_loss': 0.05374854,
#  'learning_rate': 0.070520006}
# INFO:tensorflow:Step 2300 per-step time 1.326s
# I1218 12:55:52.563704 139674028488512 model_lib_v2.py:707] Step 2300 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0032147965,
#  'Loss/localization_loss': 0.0010059793,
#  'Loss/regularization_loss': 0.029756967,
#  'Loss/total_loss': 0.03397774,
#  'learning_rate': 0.073680006}
# I1218 12:55:52.564033 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0032147965,
#  'Loss/localization_loss': 0.0010059793,
#  'Loss/regularization_loss': 0.029756967,
#  'Loss/total_loss': 0.03397774,
#  'learning_rate': 0.073680006}
# INFO:tensorflow:Step 2400 per-step time 1.327s
# I1218 12:58:05.292299 139674028488512 model_lib_v2.py:707] Step 2400 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.0305919,
#  'Loss/localization_loss': 0.0011949331,
#  'Loss/regularization_loss': 0.029739892,
#  'Loss/total_loss': 0.061526723,
#  'learning_rate': 0.076840006}
# I1218 12:58:05.292590 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0305919,
#  'Loss/localization_loss': 0.0011949331,
#  'Loss/regularization_loss': 0.029739892,
#  'Loss/total_loss': 0.061526723,
#  'learning_rate': 0.076840006}
# INFO:tensorflow:Step 2500 per-step time 1.326s
# I1218 13:00:17.864437 139674028488512 model_lib_v2.py:707] Step 2500 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.097475976,
#  'Loss/localization_loss': 0.0020820145,
#  'Loss/regularization_loss': 0.03014469,
#  'Loss/total_loss': 0.12970269,
#  'learning_rate': 0.08}
# I1218 13:00:17.864743 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.097475976,
#  'Loss/localization_loss': 0.0020820145,
#  'Loss/regularization_loss': 0.03014469,
#  'Loss/total_loss': 0.12970269,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 2600 per-step time 1.329s
# I1218 13:02:30.729281 139674028488512 model_lib_v2.py:707] Step 2600 per-step time 1.329s
# INFO:tensorflow:{'Loss/classification_loss': 0.11771465,
#  'Loss/localization_loss': 0.0025240018,
#  'Loss/regularization_loss': 0.032095008,
#  'Loss/total_loss': 0.15233366,
#  'learning_rate': 0.079999976}
# I1218 13:02:30.729620 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11771465,
#  'Loss/localization_loss': 0.0025240018,
#  'Loss/regularization_loss': 0.032095008,
#  'Loss/total_loss': 0.15233366,
#  'learning_rate': 0.079999976}
# INFO:tensorflow:Step 2700 per-step time 1.326s
# I1218 13:04:43.370238 139674028488512 model_lib_v2.py:707] Step 2700 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.03966166,
#  'Loss/localization_loss': 0.001527216,
#  'Loss/regularization_loss': 0.032100417,
#  'Loss/total_loss': 0.07328929,
#  'learning_rate': 0.07999991}
# I1218 13:04:43.370536 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.03966166,
#  'Loss/localization_loss': 0.001527216,
#  'Loss/regularization_loss': 0.032100417,
#  'Loss/total_loss': 0.07328929,
#  'learning_rate': 0.07999991}
# INFO:tensorflow:Step 2800 per-step time 1.326s
# I1218 13:06:55.992187 139674028488512 model_lib_v2.py:707] Step 2800 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.07730484,
#  'Loss/localization_loss': 0.0018206106,
#  'Loss/regularization_loss': 0.032048415,
#  'Loss/total_loss': 0.11117387,
#  'learning_rate': 0.0799998}
# I1218 13:06:55.992476 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.07730484,
#  'Loss/localization_loss': 0.0018206106,
#  'Loss/regularization_loss': 0.032048415,
#  'Loss/total_loss': 0.11117387,
#  'learning_rate': 0.0799998}
# INFO:tensorflow:Step 2900 per-step time 1.326s
# I1218 13:09:08.611096 139674028488512 model_lib_v2.py:707] Step 2900 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.03893497,
#  'Loss/localization_loss': 0.0017203727,
#  'Loss/regularization_loss': 0.032028712,
#  'Loss/total_loss': 0.07268406,
#  'learning_rate': 0.07999964}
# I1218 13:09:08.611448 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.03893497,
#  'Loss/localization_loss': 0.0017203727,
#  'Loss/regularization_loss': 0.032028712,
#  'Loss/total_loss': 0.07268406,
#  'learning_rate': 0.07999964}
# INFO:tensorflow:Step 3000 per-step time 1.327s
# I1218 13:11:21.287859 139674028488512 model_lib_v2.py:707] Step 3000 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.011067288,
#  'Loss/localization_loss': 0.0016802099,
#  'Loss/regularization_loss': 0.032051597,
#  'Loss/total_loss': 0.044799097,
#  'learning_rate': 0.07999944}
# I1218 13:11:21.288139 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.011067288,
#  'Loss/localization_loss': 0.0016802099,
#  'Loss/regularization_loss': 0.032051597,
#  'Loss/total_loss': 0.044799097,
#  'learning_rate': 0.07999944}
# INFO:tensorflow:Step 3100 per-step time 1.350s
# I1218 13:13:36.281805 139674028488512 model_lib_v2.py:707] Step 3100 per-step time 1.350s
# INFO:tensorflow:{'Loss/classification_loss': 0.014617564,
#  'Loss/localization_loss': 0.0010596078,
#  'Loss/regularization_loss': 0.031972926,
#  'Loss/total_loss': 0.0476501,
#  'learning_rate': 0.07999919}
# I1218 13:13:36.282098 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.014617564,
#  'Loss/localization_loss': 0.0010596078,
#  'Loss/regularization_loss': 0.031972926,
#  'Loss/total_loss': 0.0476501,
#  'learning_rate': 0.07999919}
# INFO:tensorflow:Step 3200 per-step time 1.328s
# I1218 13:15:49.107561 139674028488512 model_lib_v2.py:707] Step 3200 per-step time 1.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.013808474,
#  'Loss/localization_loss': 0.0008651172,
#  'Loss/regularization_loss': 0.031879712,
#  'Loss/total_loss': 0.046553303,
#  'learning_rate': 0.0799989}
# I1218 13:15:49.107857 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.013808474,
#  'Loss/localization_loss': 0.0008651172,
#  'Loss/regularization_loss': 0.031879712,
#  'Loss/total_loss': 0.046553303,
#  'learning_rate': 0.0799989}
# INFO:tensorflow:Step 3300 per-step time 1.328s
# I1218 13:18:01.871603 139674028488512 model_lib_v2.py:707] Step 3300 per-step time 1.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.010618876,
#  'Loss/localization_loss': 0.00088139455,
#  'Loss/regularization_loss': 0.031774346,
#  'Loss/total_loss': 0.04327462,
#  'learning_rate': 0.07999857}
# I1218 13:18:01.871953 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.010618876,
#  'Loss/localization_loss': 0.00088139455,
#  'Loss/regularization_loss': 0.031774346,
#  'Loss/total_loss': 0.04327462,
#  'learning_rate': 0.07999857}
# INFO:tensorflow:Step 3400 per-step time 1.327s
# I1218 13:20:14.556159 139674028488512 model_lib_v2.py:707] Step 3400 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.0059707514,
#  'Loss/localization_loss': 0.0007129017,
#  'Loss/regularization_loss': 0.031668697,
#  'Loss/total_loss': 0.038352348,
#  'learning_rate': 0.07999819}
# I1218 13:20:14.556449 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0059707514,
#  'Loss/localization_loss': 0.0007129017,
#  'Loss/regularization_loss': 0.031668697,
#  'Loss/total_loss': 0.038352348,
#  'learning_rate': 0.07999819}
# INFO:tensorflow:Step 3500 per-step time 1.325s
# I1218 13:22:27.106251 139674028488512 model_lib_v2.py:707] Step 3500 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.00898454,
#  'Loss/localization_loss': 0.00074334815,
#  'Loss/regularization_loss': 0.031566292,
#  'Loss/total_loss': 0.04129418,
#  'learning_rate': 0.07999776}
# I1218 13:22:27.106635 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00898454,
#  'Loss/localization_loss': 0.00074334815,
#  'Loss/regularization_loss': 0.031566292,
#  'Loss/total_loss': 0.04129418,
#  'learning_rate': 0.07999776}
# INFO:tensorflow:Step 3600 per-step time 1.325s
# I1218 13:24:39.629721 139674028488512 model_lib_v2.py:707] Step 3600 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.006921092,
#  'Loss/localization_loss': 0.0006879862,
#  'Loss/regularization_loss': 0.031460986,
#  'Loss/total_loss': 0.039070062,
#  'learning_rate': 0.0799973}
# I1218 13:24:39.630006 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.006921092,
#  'Loss/localization_loss': 0.0006879862,
#  'Loss/regularization_loss': 0.031460986,
#  'Loss/total_loss': 0.039070062,
#  'learning_rate': 0.0799973}
# INFO:tensorflow:Step 3700 per-step time 1.326s
# I1218 13:26:52.184841 139674028488512 model_lib_v2.py:707] Step 3700 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0046100016,
#  'Loss/localization_loss': 0.0005995471,
#  'Loss/regularization_loss': 0.031363998,
#  'Loss/total_loss': 0.036573548,
#  'learning_rate': 0.07999679}
# I1218 13:26:52.185216 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0046100016,
#  'Loss/localization_loss': 0.0005995471,
#  'Loss/regularization_loss': 0.031363998,
#  'Loss/total_loss': 0.036573548,
#  'learning_rate': 0.07999679}
# INFO:tensorflow:Step 3800 per-step time 1.326s
# I1218 13:29:04.799944 139674028488512 model_lib_v2.py:707] Step 3800 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0062719327,
#  'Loss/localization_loss': 0.0007865962,
#  'Loss/regularization_loss': 0.03125676,
#  'Loss/total_loss': 0.03831529,
#  'learning_rate': 0.07999623}
# I1218 13:29:04.800235 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0062719327,
#  'Loss/localization_loss': 0.0007865962,
#  'Loss/regularization_loss': 0.03125676,
#  'Loss/total_loss': 0.03831529,
#  'learning_rate': 0.07999623}
# INFO:tensorflow:Step 3900 per-step time 1.328s
# I1218 13:31:17.551656 139674028488512 model_lib_v2.py:707] Step 3900 per-step time 1.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.00079001056,
#  'Loss/localization_loss': 0.0006140259,
#  'Loss/regularization_loss': 0.03115028,
#  'Loss/total_loss': 0.032554314,
#  'learning_rate': 0.07999563}
# I1218 13:31:17.551964 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00079001056,
#  'Loss/localization_loss': 0.0006140259,
#  'Loss/regularization_loss': 0.03115028,
#  'Loss/total_loss': 0.032554314,
#  'learning_rate': 0.07999563}
# INFO:tensorflow:Step 4000 per-step time 1.326s
# I1218 13:33:30.129729 139674028488512 model_lib_v2.py:707] Step 4000 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0011327617,
#  'Loss/localization_loss': 0.0005001049,
#  'Loss/regularization_loss': 0.031042937,
#  'Loss/total_loss': 0.032675803,
#  'learning_rate': 0.079994984}
# I1218 13:33:30.130059 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0011327617,
#  'Loss/localization_loss': 0.0005001049,
#  'Loss/regularization_loss': 0.031042937,
#  'Loss/total_loss': 0.032675803,
#  'learning_rate': 0.079994984}
# INFO:tensorflow:Step 4100 per-step time 1.350s
# I1218 13:35:45.133238 139674028488512 model_lib_v2.py:707] Step 4100 per-step time 1.350s
# INFO:tensorflow:{'Loss/classification_loss': 0.00068574864,
#  'Loss/localization_loss': 0.00055407267,
#  'Loss/regularization_loss': 0.030934542,
#  'Loss/total_loss': 0.032174364,
#  'learning_rate': 0.07999428}
# I1218 13:35:45.133584 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00068574864,
#  'Loss/localization_loss': 0.00055407267,
#  'Loss/regularization_loss': 0.030934542,
#  'Loss/total_loss': 0.032174364,
#  'learning_rate': 0.07999428}
# INFO:tensorflow:Step 4200 per-step time 1.326s
# I1218 13:37:57.756767 139674028488512 model_lib_v2.py:707] Step 4200 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.0013287361,
#  'Loss/localization_loss': 0.0005177325,
#  'Loss/regularization_loss': 0.03082491,
#  'Loss/total_loss': 0.03267138,
#  'learning_rate': 0.07999355}
# I1218 13:37:57.757055 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0013287361,
#  'Loss/localization_loss': 0.0005177325,
#  'Loss/regularization_loss': 0.03082491,
#  'Loss/total_loss': 0.03267138,
#  'learning_rate': 0.07999355}
# INFO:tensorflow:Step 4300 per-step time 1.325s
# I1218 13:40:10.274291 139674028488512 model_lib_v2.py:707] Step 4300 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.017574621,
#  'Loss/localization_loss': 0.0007065176,
#  'Loss/regularization_loss': 0.030715136,
#  'Loss/total_loss': 0.048996273,
#  'learning_rate': 0.07999277}
# I1218 13:40:10.274608 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.017574621,
#  'Loss/localization_loss': 0.0007065176,
#  'Loss/regularization_loss': 0.030715136,
#  'Loss/total_loss': 0.048996273,
#  'learning_rate': 0.07999277}
# INFO:tensorflow:Step 4400 per-step time 1.327s
# I1218 13:42:22.955603 139674028488512 model_lib_v2.py:707] Step 4400 per-step time 1.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.016672622,
#  'Loss/localization_loss': 0.0004885933,
#  'Loss/regularization_loss': 0.030609734,
#  'Loss/total_loss': 0.04777095,
#  'learning_rate': 0.07999195}
# ...
#  'learning_rate': 0.079981245}
# INFO:tensorflow:Step 5500 per-step time 1.323s
# I1218 14:06:42.930320 139674028488512 model_lib_v2.py:707] Step 5500 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.0002731297,
#  'Loss/localization_loss': 0.00030790782,
#  'Loss/regularization_loss': 0.029467028,
#  'Loss/total_loss': 0.030048065,
#  'learning_rate': 0.07997993}
# I1218 14:06:42.930609 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0002731297,
#  'Loss/localization_loss': 0.00030790782,
#  'Loss/regularization_loss': 0.029467028,
#  'Loss/total_loss': 0.030048065,
#  'learning_rate': 0.07997993}
# INFO:tensorflow:Step 5600 per-step time 1.324s
# I1218 14:08:55.338658 139674028488512 model_lib_v2.py:707] Step 5600 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.015143947,
#  'Loss/localization_loss': 0.0005126643,
#  'Loss/regularization_loss': 0.029365284,
#  'Loss/total_loss': 0.045021895,
#  'learning_rate': 0.07997857}
# I1218 14:08:55.338953 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.015143947,
#  'Loss/localization_loss': 0.0005126643,
#  'Loss/regularization_loss': 0.029365284,
#  'Loss/total_loss': 0.045021895,
#  'learning_rate': 0.07997857}
# INFO:tensorflow:Step 5700 per-step time 1.324s
# I1218 14:11:07.738847 139674028488512 model_lib_v2.py:707] Step 5700 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.0009997585,
#  'Loss/localization_loss': 0.00038088768,
#  'Loss/regularization_loss': 0.029262919,
#  'Loss/total_loss': 0.030643566,
#  'learning_rate': 0.07997716}
# I1218 14:11:07.739173 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0009997585,
#  'Loss/localization_loss': 0.00038088768,
#  'Loss/regularization_loss': 0.029262919,
#  'Loss/total_loss': 0.030643566,
#  'learning_rate': 0.07997716}
# INFO:tensorflow:Step 5800 per-step time 1.326s
# I1218 14:13:20.335038 139674028488512 model_lib_v2.py:707] Step 5800 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.022028143,
#  'Loss/localization_loss': 0.0006601964,
#  'Loss/regularization_loss': 0.029160384,
#  'Loss/total_loss': 0.051848724,
#  'learning_rate': 0.07997571}
# I1218 14:13:20.335323 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.022028143,
#  'Loss/localization_loss': 0.0006601964,
#  'Loss/regularization_loss': 0.029160384,
#  'Loss/total_loss': 0.051848724,
#  'learning_rate': 0.07997571}
# INFO:tensorflow:Step 5900 per-step time 1.324s
# I1218 14:15:32.696697 139674028488512 model_lib_v2.py:707] Step 5900 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.015556165,
#  'Loss/localization_loss': 0.00046184813,
#  'Loss/regularization_loss': 0.029065661,
#  'Loss/total_loss': 0.04508367,
#  'learning_rate': 0.07997422}
# I1218 14:15:32.696990 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.015556165,
#  'Loss/localization_loss': 0.00046184813,
#  'Loss/regularization_loss': 0.029065661,
#  'Loss/total_loss': 0.04508367,
#  'learning_rate': 0.07997422}
# INFO:tensorflow:Step 6000 per-step time 1.324s
# I1218 14:17:45.143682 139674028488512 model_lib_v2.py:707] Step 6000 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.02829183,
#  'Loss/localization_loss': 0.00047191212,
#  'Loss/regularization_loss': 0.028963841,
#  'Loss/total_loss': 0.057727583,
#  'learning_rate': 0.07997268}
# I1218 14:17:45.143966 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.02829183,
#  'Loss/localization_loss': 0.00047191212,
#  'Loss/regularization_loss': 0.028963841,
#  'Loss/total_loss': 0.057727583,
#  'learning_rate': 0.07997268}
# INFO:tensorflow:Step 6100 per-step time 1.347s
# I1218 14:19:59.896766 139674028488512 model_lib_v2.py:707] Step 6100 per-step time 1.347s
# INFO:tensorflow:{'Loss/classification_loss': 0.0002598165,
#  'Loss/localization_loss': 0.00025331596,
#  'Loss/regularization_loss': 0.028862784,
#  'Loss/total_loss': 0.029375916,
#  'learning_rate': 0.0799711}
# I1218 14:19:59.897186 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0002598165,
#  'Loss/localization_loss': 0.00025331596,
#  'Loss/regularization_loss': 0.028862784,
#  'Loss/total_loss': 0.029375916,
#  'learning_rate': 0.0799711}
# INFO:tensorflow:Step 6200 per-step time 1.325s
# I1218 14:22:12.342828 139674028488512 model_lib_v2.py:707] Step 6200 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.00023452187,
#  'Loss/localization_loss': 0.00026134576,
#  'Loss/regularization_loss': 0.028763471,
#  'Loss/total_loss': 0.029259339,
#  'learning_rate': 0.07996947}
# I1218 14:22:12.343102 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00023452187,
#  'Loss/localization_loss': 0.00026134576,
#  'Loss/regularization_loss': 0.028763471,
#  'Loss/total_loss': 0.029259339,
#  'learning_rate': 0.07996947}
# INFO:tensorflow:Step 6300 per-step time 1.323s
# I1218 14:24:24.665994 139674028488512 model_lib_v2.py:707] Step 6300 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.025087714,
#  'Loss/localization_loss': 0.00054926024,
#  'Loss/regularization_loss': 0.028664786,
#  'Loss/total_loss': 0.05430176,
#  'learning_rate': 0.0799678}
# I1218 14:24:24.666309 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.025087714,
#  'Loss/localization_loss': 0.00054926024,
#  'Loss/regularization_loss': 0.028664786,
#  'Loss/total_loss': 0.05430176,
#  'learning_rate': 0.0799678}
# INFO:tensorflow:Step 6400 per-step time 1.324s
# I1218 14:26:37.046492 139674028488512 model_lib_v2.py:707] Step 6400 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.008810211,
#  'Loss/localization_loss': 0.00040373942,
#  'Loss/regularization_loss': 0.028564915,
#  'Loss/total_loss': 0.037778866,
#  'learning_rate': 0.07996608}
# I1218 14:26:37.046813 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.008810211,
#  'Loss/localization_loss': 0.00040373942,
#  'Loss/regularization_loss': 0.028564915,
#  'Loss/total_loss': 0.037778866,
#  'learning_rate': 0.07996608}
# INFO:tensorflow:Step 6500 per-step time 1.325s
# I1218 14:28:49.593973 139674028488512 model_lib_v2.py:707] Step 6500 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.008763585,
#  'Loss/localization_loss': 0.00034832218,
#  'Loss/regularization_loss': 0.028466523,
#  'Loss/total_loss': 0.03757843,
#  'learning_rate': 0.079964325}
# I1218 14:28:49.594281 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.008763585,
#  'Loss/localization_loss': 0.00034832218,
#  'Loss/regularization_loss': 0.028466523,
#  'Loss/total_loss': 0.03757843,
#  'learning_rate': 0.079964325}
# INFO:tensorflow:Step 6600 per-step time 1.323s
# I1218 14:31:01.937081 139674028488512 model_lib_v2.py:707] Step 6600 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.043009166,
#  'Loss/localization_loss': 0.0004947498,
#  'Loss/regularization_loss': 0.028368095,
#  'Loss/total_loss': 0.07187201,
#  'learning_rate': 0.079962514}
# I1218 14:31:01.937452 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.043009166,
#  'Loss/localization_loss': 0.0004947498,
#  'Loss/regularization_loss': 0.028368095,
#  'Loss/total_loss': 0.07187201,
#  'learning_rate': 0.079962514}
# INFO:tensorflow:Step 6700 per-step time 1.323s
# I1218 14:33:14.208898 139674028488512 model_lib_v2.py:707] Step 6700 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.00013928772,
#  'Loss/localization_loss': 0.00024063575,
#  'Loss/regularization_loss': 0.02827042,
#  'Loss/total_loss': 0.028650343,
#  'learning_rate': 0.07996067}
# I1218 14:33:14.209244 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00013928772,
#  'Loss/localization_loss': 0.00024063575,
#  'Loss/regularization_loss': 0.02827042,
#  'Loss/total_loss': 0.028650343,
#  'learning_rate': 0.07996067}
# INFO:tensorflow:Step 6800 per-step time 1.325s
# I1218 14:35:26.680180 139674028488512 model_lib_v2.py:707] Step 6800 per-step time 1.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.015745856,
#  'Loss/localization_loss': 0.00033855397,
#  'Loss/regularization_loss': 0.028172435,
#  'Loss/total_loss': 0.044256844,
#  'learning_rate': 0.079958774}
# I1218 14:35:26.680473 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.015745856,
#  'Loss/localization_loss': 0.00033855397,
#  'Loss/regularization_loss': 0.028172435,
#  'Loss/total_loss': 0.044256844,
#  'learning_rate': 0.079958774}
# INFO:tensorflow:Step 6900 per-step time 1.323s
# I1218 14:37:39.005473 139674028488512 model_lib_v2.py:707] Step 6900 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.000120221004,
#  'Loss/localization_loss': 0.00021096996,
#  'Loss/regularization_loss': 0.028078651,
#  'Loss/total_loss': 0.028409842,
#  'learning_rate': 0.07995682}
# I1218 14:37:39.005767 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.000120221004,
#  'Loss/localization_loss': 0.00021096996,
#  'Loss/regularization_loss': 0.028078651,
#  'Loss/total_loss': 0.028409842,
#  'learning_rate': 0.07995682}
# INFO:tensorflow:Step 7000 per-step time 1.324s
# I1218 14:39:51.407291 139674028488512 model_lib_v2.py:707] Step 7000 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.0054440815,
#  'Loss/localization_loss': 0.00026272473,
#  'Loss/regularization_loss': 0.027983222,
#  'Loss/total_loss': 0.03369003,
#  'learning_rate': 0.07995484}
# I1218 14:39:51.407595 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0054440815,
#  'Loss/localization_loss': 0.00026272473,
#  'Loss/regularization_loss': 0.027983222,
#  'Loss/total_loss': 0.03369003,
#  'learning_rate': 0.07995484}
# INFO:tensorflow:Step 7100 per-step time 1.348s
# I1218 14:42:06.220288 139674028488512 model_lib_v2.py:707] Step 7100 per-step time 1.348s
# INFO:tensorflow:{'Loss/classification_loss': 0.00025427525,
#  'Loss/localization_loss': 0.00035306622,
#  'Loss/regularization_loss': 0.027886188,
#  'Loss/total_loss': 0.02849353,
#  'learning_rate': 0.07995281}
# I1218 14:42:06.220617 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00025427525,
#  'Loss/localization_loss': 0.00035306622,
#  'Loss/regularization_loss': 0.027886188,
#  'Loss/total_loss': 0.02849353,
#  'learning_rate': 0.07995281}
# INFO:tensorflow:Step 7200 per-step time 1.324s
# I1218 14:44:18.635720 139674028488512 model_lib_v2.py:707] Step 7200 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.0005387788,
#  'Loss/localization_loss': 0.00018761086,
#  'Loss/regularization_loss': 0.027795801,
#  'Loss/total_loss': 0.028522192,
#  'learning_rate': 0.07995074}
# I1218 14:44:18.636040 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0005387788,
#  'Loss/localization_loss': 0.00018761086,
#  'Loss/regularization_loss': 0.027795801,
#  'Loss/total_loss': 0.028522192,
#  'learning_rate': 0.07995074}
# INFO:tensorflow:Step 7300 per-step time 1.324s
# I1218 14:46:31.035650 139674028488512 model_lib_v2.py:707] Step 7300 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.011210385,
#  'Loss/localization_loss': 0.00031664522,
#  'Loss/regularization_loss': 0.027700689,
#  'Loss/total_loss': 0.03922772,
#  'learning_rate': 0.07994863}
# I1218 14:46:31.035953 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.011210385,
#  'Loss/localization_loss': 0.00031664522,
#  'Loss/regularization_loss': 0.027700689,
#  'Loss/total_loss': 0.03922772,
#  'learning_rate': 0.07994863}
# INFO:tensorflow:Step 7400 per-step time 1.324s
# I1218 14:48:43.419532 139674028488512 model_lib_v2.py:707] Step 7400 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.006971951,
#  'Loss/localization_loss': 0.00031514728,
#  'Loss/regularization_loss': 0.02760629,
#  'Loss/total_loss': 0.03489339,
#  'learning_rate': 0.07994646}
# I1218 14:48:43.419809 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.006971951,
#  'Loss/localization_loss': 0.00031514728,
#  'Loss/regularization_loss': 0.02760629,
#  'Loss/total_loss': 0.03489339,
#  'learning_rate': 0.07994646}
# INFO:tensorflow:Step 7500 per-step time 1.326s
# I1218 14:50:55.996474 139674028488512 model_lib_v2.py:707] Step 7500 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.007196168,
#  'Loss/localization_loss': 0.00024712956,
#  'Loss/regularization_loss': 0.027512778,
#  'Loss/total_loss': 0.034956075,
#  'learning_rate': 0.07994425}
# I1218 14:50:55.996776 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.007196168,
#  'Loss/localization_loss': 0.00024712956,
#  'Loss/regularization_loss': 0.027512778,
#  'Loss/total_loss': 0.034956075,
#  'learning_rate': 0.07994425}
# INFO:tensorflow:Step 7600 per-step time 1.324s
# I1218 14:53:08.423403 139674028488512 model_lib_v2.py:707] Step 7600 per-step time 1.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.00011957144,
#  'Loss/localization_loss': 0.00026838965,
#  'Loss/regularization_loss': 0.027417993,
#  'Loss/total_loss': 0.027805954,
#  'learning_rate': 0.079942}
# I1218 14:53:08.423731 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00011957144,
#  'Loss/localization_loss': 0.00026838965,
#  'Loss/regularization_loss': 0.027417993,
#  'Loss/total_loss': 0.027805954,
#  'learning_rate': 0.079942}
# INFO:tensorflow:Step 7700 per-step time 1.322s
# I1218 14:55:20.666278 139674028488512 model_lib_v2.py:707] Step 7700 per-step time 1.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.0002257784,
#  'Loss/localization_loss': 0.00021815917,
#  'Loss/regularization_loss': 0.027323464,
#  'Loss/total_loss': 0.027767401,
#  'learning_rate': 0.07993971}
# I1218 14:55:20.666593 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0002257784,
#  'Loss/localization_loss': 0.00021815917,
#  'Loss/regularization_loss': 0.027323464,
#  'Loss/total_loss': 0.027767401,
#  'learning_rate': 0.07993971}
# INFO:tensorflow:Step 7800 per-step time 1.323s
# I1218 14:57:32.987003 139674028488512 model_lib_v2.py:707] Step 7800 per-step time 1.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.00017675609,
#  'Loss/localization_loss': 0.00026446587,
#  'Loss/regularization_loss': 0.027237918,
#  'Loss/total_loss': 0.02767914,
#  'learning_rate': 0.07993737}
# I1218 14:57:32.987305 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00017675609,
#  'Loss/localization_loss': 0.00026446587,
#  'Loss/regularization_loss': 0.027237918,
#  'Loss/total_loss': 0.02767914,
#  'learning_rate': 0.07993737}
# INFO:tensorflow:Step 7900 per-step time 1.326s
# I1218 14:59:45.551324 139674028488512 model_lib_v2.py:707] Step 7900 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.00013095941,
#  'Loss/localization_loss': 0.00022248171,
#  'Loss/regularization_loss': 0.027146814,
#  'Loss/total_loss': 0.027500255,
#  'learning_rate': 0.079934984}
# I1218 14:59:45.551652 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.00013095941,
#  'Loss/localization_loss': 0.00022248171,
#  'Loss/regularization_loss': 0.027146814,
#  'Loss/total_loss': 0.027500255,
#  'learning_rate': 0.079934984}
# INFO:tensorflow:Step 8000 per-step time 1.326s
# I1218 15:01:58.100931 139674028488512 model_lib_v2.py:707] Step 8000 per-step time 1.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.014775892,
#  'Loss/localization_loss': 0.00033503145,
#  'Loss/regularization_loss': 0.02705393,
#  'Loss/total_loss': 0.04216485,
#  'learning_rate': 0.079932556}
# I1218 15:01:58.101202 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.014775892,
#  'Loss/localization_loss': 0.00033503145,
#  'Loss/regularization_loss': 0.02705393,
#  'Loss/total_loss': 0.04216485,
#  'learning_rate': 0.079932556}
# INFO:tensorflow:Step 8100 per-step time 1.354s
# I1218 15:04:13.536574 139674028488512 model_lib_v2.py:707] Step 8100 per-step time 1.354s
# INFO:tensorflow:{'Loss/classification_loss': 0.0028721006,
#  'Loss/localization_loss': 0.00023993434,
#  'Loss/regularization_loss': 0.026964212,
#  'Loss/total_loss': 0.030076247,
#  'learning_rate': 0.079930075}
# I1218 15:04:13.536929 139674028488512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0028721006,
#  'Loss/localization_loss': 0.00023993434,
#  'Loss/regularization_loss': 0.026964212,
#  'Loss/total_loss': 0.030076247,
#  'learning_rate': 0.079930075}

# %%
# !mkdir -p {paths['exported_model']}
export_command = 'python {} --input_type image_tensor --pipeline_config_path {} --trained_checkpoint_dir {} --output_directory {}'.format(
    paths['export_script'],
    paths['pipeline'],
    paths['model'],
    paths['exported_model']
)

print(export_command)
# Out:
# python /home/jupyter/cse496/Tensorflow/models/research/object_detection/exporter_main_v2.py --input_type image_tensor --pipeline_config_path /home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32/pipeline.config --trained_checkpoint_dir /home/jupyter/cse496/Tensorflow/workspace/digital-meter/models/efficientdet_d1_coco17_tpu-32 --output_directory /home/jupyter/cse496/Tensorflow/workspace/digital-meter/exported_models/efficientdet_d1_coco17_tpu-32

# %%
# !{export_command}
# Out:
# 2022-12-19 13:54:44.891090: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 13:54:45.943444: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-19 13:54:45.943544: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-12-19 13:54:45.943563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-19 13:54:48.305982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:48.318904: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:48.320911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:48.329423: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 13:54:48.330180: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:48.332173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:48.334152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:49.132044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:49.135458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:49.138388: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 13:54:49.141271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13582 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I1219 13:54:49.281287 140029330655040 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1219 13:54:49.281481 140029330655040 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I1219 13:54:49.281545 140029330655040 ssd_efficientnet_bifpn_feature_extractor.py:154] EfficientDet BiFPN num iterations: 4
# I1219 13:54:49.285679 140029330655040 efficientnet_model.py:143] round_filter input=32 output=32
# I1219 13:54:49.320739 140029330655040 efficientnet_model.py:143] round_filter input=32 output=32
# I1219 13:54:49.320846 140029330655040 efficientnet_model.py:143] round_filter input=16 output=16
# I1219 13:54:49.473366 140029330655040 efficientnet_model.py:143] round_filter input=16 output=16
# I1219 13:54:49.473496 140029330655040 efficientnet_model.py:143] round_filter input=24 output=24
# I1219 13:54:49.746466 140029330655040 efficientnet_model.py:143] round_filter input=24 output=24
# I1219 13:54:49.746590 140029330655040 efficientnet_model.py:143] round_filter input=40 output=40
# I1219 13:54:50.017449 140029330655040 efficientnet_model.py:143] round_filter input=40 output=40
# I1219 13:54:50.017598 140029330655040 efficientnet_model.py:143] round_filter input=80 output=80
# I1219 13:54:50.496134 140029330655040 efficientnet_model.py:143] round_filter input=80 output=80
# I1219 13:54:50.496297 140029330655040 efficientnet_model.py:143] round_filter input=112 output=112
# I1219 13:54:50.849460 140029330655040 efficientnet_model.py:143] round_filter input=112 output=112
# I1219 13:54:50.849640 140029330655040 efficientnet_model.py:143] round_filter input=192 output=192
# I1219 13:54:51.296627 140029330655040 efficientnet_model.py:143] round_filter input=192 output=192
# I1219 13:54:51.296771 140029330655040 efficientnet_model.py:143] round_filter input=320 output=320
# I1219 13:54:51.478600 140029330655040 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1219 13:54:51.521246 140029330655040 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1219 13:54:55.568502 140029330655040 deprecation.py:356] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1219 13:54:55.639115 140029330655040 deprecation.py:628] From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5a90045550>, because it is not built.
# W1219 13:55:22.089257 140029330655040 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5a90045550>, because it is not built.

# %% [markdown]
# # Test

# %%
detect_fn = tf.saved_model.load(os.path.join(paths['exported_model'],'saved_model'))

# %%
def load_image_into_numpy_array(path):
  return pipe(
      path,
      Image.open,
      lambda x: x.convert('RGB'),
      np.array
  )

def detect(image_path):
  return pipe(
      image_path,
      load_image_into_numpy_array,
      lambda im: pipe(
        im,
        tf.convert_to_tensor,
        lambda x: x[tf.newaxis, ...],
        detect_fn,
        lambda detections: merge(detections, {'image': im})
      )
  )

# %%
def get_imgs(path):
    return pipe(
        os.path.join(path),
        os.listdir,
        map(lambda x: os.path.join(path,x)),
        filter(lambda x: any((
            x.endswith('jpeg'),
            x.endswith('jpg')
        ))),
        take(10)
    )

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# import warnings
# warnings.filterwarnings('ignore')
from object_detection.utils import visualization_utils as viz_utils

#for image_path in get_imgs(os.path.join(paths['images'],'train')):
for image_path in get_imgs('/home/jupyter/cse496/Tensorflow/workspace/digital-meter/images/test'):
  detections = detect(image_path)
  viz_utils.visualize_boxes_and_labels_on_image_array(
          detections['image'],
          detections['detection_boxes'][0].numpy(),
          (detections['detection_classes'][0].numpy()).astype(int),
          detections['detection_scores'][0].numpy(),
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=100,     
          min_score_thresh=.5,      
          line_thickness=12,
          skip_scores=True,
          agnostic_mode=False
  )
  # %matplotlib inline
  plt.figure(figsize = (24,24))
  plt.imshow(detections['image'])
  plt.axis('off')
  plt.show()
  print ([ int(value) for index,value in enumerate(detections['detection_classes'][0]) if detections['detection_scores'][0][index] > 0.5])
# Out:
# [10]
# []
# []
# [10, 5, 7]
# []
# []
# [10, 10, 10]
# [10, 2, 3]
# []
# [2]

# %% [markdown]
# # Reset GPU

# %%
from numba import cuda 
device = cuda.get_current_device()
device.reset()
